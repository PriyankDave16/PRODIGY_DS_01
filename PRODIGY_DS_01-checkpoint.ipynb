# %% [markdown]
# # Population data visualization

# %% [markdown]
# # Libraires

# %%
import pandas as pd
import numpy as np 
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # Understanding the data

# %%
df=pd.read_csv("population.csv",skiprows=3)

# %%
df.head(5)
# Out:
#                   Country Name Country Code     Indicator Name Indicator Code  \
# 0                        Aruba          ABW  Population, total    SP.POP.TOTL
# 1  Africa Eastern and Southern          AFE  Population, total    SP.POP.TOTL
# 2                  Afghanistan          AFG  Population, total    SP.POP.TOTL
# 3   Africa Western and Central          AFW  Population, total    SP.POP.TOTL
# 4                       Angola          AGO  Population, total    SP.POP.TOTL
#
#           1960         1961         1962         1963         1964  \
# 0      54922.0      55578.0      56320.0      57002.0      57619.0
# 1  130075728.0  133534923.0  137171659.0  140945536.0  144904094.0
# 2    9035043.0    9214083.0    9404406.0    9604487.0    9814318.0
# 3   97630925.0   99706674.0  101854756.0  104089175.0  106388440.0
# 4    5231654.0    5301583.0    5354310.0    5408320.0    5464187.0
#
#           1965  ...         2016         2017         2018         2019  \
# ...

# %%
df.tail(5)
# Out:
#      Country Name Country Code     Indicator Name Indicator Code        1960  \
# 261        Kosovo          XKX  Population, total    SP.POP.TOTL    984846.0
# 262   Yemen, Rep.          YEM  Population, total    SP.POP.TOTL   5532301.0
# 263  South Africa          ZAF  Population, total    SP.POP.TOTL  16440172.0
# 264        Zambia          ZMB  Population, total    SP.POP.TOTL   3153729.0
# 265      Zimbabwe          ZWE  Population, total    SP.POP.TOTL   3809389.0
#
#            1961        1962        1963        1964        1965  ...  \
# 261   1011421.0   1036950.0   1062737.0   1090270.0   1120168.0  ...
# 262   5655232.0   5782221.0   5911135.0   6048006.0   6195593.0  ...
# 263  16908035.0  17418522.0  17954564.0  18511361.0  19089380.0  ...
# 264   3254086.0   3358099.0   3465907.0   3577017.0   3692086.0  ...
# 265   3930401.0   4055959.0   4185877.0   4320006.0   4458462.0  ...
#
#            2016        2017        2018        2019        2020        2021  \
# ...

# %%
df.columns
# Out:
# Index(['Country Name', 'Country Code', 'Indicator Name', 'Indicator Code',
#        '1960', '1961', '1962', '1963', '1964', '1965', '1966', '1967', '1968',
#        '1969', '1970', '1971', '1972', '1973', '1974', '1975', '1976', '1977',
#        '1978', '1979', '1980', '1981', '1982', '1983', '1984', '1985', '1986',
#        '1987', '1988', '1989', '1990', '1991', '1992', '1993', '1994', '1995',
#        '1996', '1997', '1998', '1999', '2000', '2001', '2002', '2003', '2004',
#        '2005', '2006', '2007', '2008', '2009', '2010', '2011', '2012', '2013',
#        '2014', '2015', '2016', '2017', '2018', '2019', '2020', '2021', '2022',
#        '2023', '2024', 'Unnamed: 69'],
#       dtype='object')

# %%
df.info
# Out:
# <bound method DataFrame.info of                     Country Name Country Code     Indicator Name  \
# 0                          Aruba          ABW  Population, total
# 1    Africa Eastern and Southern          AFE  Population, total
# 2                    Afghanistan          AFG  Population, total
# 3     Africa Western and Central          AFW  Population, total
# 4                         Angola          AGO  Population, total
# ..                           ...          ...                ...
# 261                       Kosovo          XKX  Population, total
# 262                  Yemen, Rep.          YEM  Population, total
# 263                 South Africa          ZAF  Population, total
# 264                       Zambia          ZMB  Population, total
# 265                     Zimbabwe          ZWE  Population, total
#
#     Indicator Code         1960         1961         1962         1963  \
# 0      SP.POP.TOTL      54922.0      55578.0      56320.0      57002.0
# ...

# %%
df.describe
# Out:
# <bound method NDFrame.describe of                     Country Name Country Code     Indicator Name  \
# 0                          Aruba          ABW  Population, total
# 1    Africa Eastern and Southern          AFE  Population, total
# 2                    Afghanistan          AFG  Population, total
# 3     Africa Western and Central          AFW  Population, total
# 4                         Angola          AGO  Population, total
# ..                           ...          ...                ...
# 261                       Kosovo          XKX  Population, total
# 262                  Yemen, Rep.          YEM  Population, total
# 263                 South Africa          ZAF  Population, total
# 264                       Zambia          ZMB  Population, total
# 265                     Zimbabwe          ZWE  Population, total
#
#     Indicator Code         1960         1961         1962         1963  \
# 0      SP.POP.TOTL      54922.0      55578.0      56320.0      57002.0
# ...

# %%
df.drop(['Country Name','Indicator Name'],axis=1,inplace=True)

# %% [markdown]
# # Visualization of Top 10 country by population between 2020 & 2024

# %%
total_population=df[df['Indicator Code']=='SP.POP.TOTL']
total_population_sorted=total_population.sort_values(by="2020",ascending=False)  
total_top_ten_countries=total_population_sorted.head(10)
print("top ten countries of total population\n")
print(total_top_ten_countries['Country Code'])
# Out:
# top ten countries of total population
#
# 259    WLD
# 103    IBT
# 140    LMY
# 156    MIC
# 102    IBD
# 62     EAR
# 139    LMC
# 249    UMC
# 63     EAS
# 142    LTE
# Name: Country Code, dtype: object

# %%
plt.figure(figsize =(20,6))
plt.subplot(2,2,1)
sns.barplot(x="2020",y="Country Code",data=total_top_ten_countries,palette="pastel")
plt.title("top ten countries by population(2025)",fontsize=10)
plt.title("total population",fontsize=10)
plt.ylabel("country",fontsize=10)
plt.show()

plt.figure(figsize =(20,6))
plt.subplot(2,2,2)
sns.barplot(x="2024",y="Country Code",data=total_top_ten_countries,palette="pastel")
plt.title("top ten countries by population(2025)",fontsize=10)
plt.title("total population",fontsize=10)
plt.ylabel("country",fontsize=10)
plt.show()
# Out:
# C:\Users\WELCOME\AppData\Local\Temp\ipykernel_4660\825544285.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x="2020",y="Country Code",data=total_top_ten_countries,palette="pastel")
# C:\Users\WELCOME\AppData\Local\Temp\ipykernel_4660\825544285.py:11: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x="2024",y="Country Code",data=total_top_ten_countries,palette="pastel")

# %% [markdown]
# # Visualization of bottom ten countries Between 2020 & 2024

# %%
total_population=df[df['Indicator Code']=='SP.POP.TOTL']
total_population_sorted=total_population.sort_values(by="2024",ascending=True)  
total_top_ten_countries=total_population_sorted.head(10)
print("Bottom ten countries of total population\n")
print(total_top_ten_countries['Country Code'])
# Out:
# Bottom ten countries of total population
#
# 245    TUV
# 179    NRU
# 188    PLW
# 147    MAF
# 212    SMR
# 155    MHL
# 149    MCO
# 84     GIB
# 255    VGB
# 137    LIE
# Name: Country Code, dtype: object

# %%
plt.figure(figsize =(20,6))
plt.subplot(2,2,1)
sns.barplot(x="2020",y="Country Code",data=total_top_ten_countries,palette="pastel")
plt.title("bottom ten countries by population(2024)",fontsize=10)
plt.title("total population",fontsize=10)
plt.ylabel("country",fontsize=10)
plt.show()

plt.figure(figsize =(20,6))
plt.subplot(2,2,2)
sns.barplot(x="2024",y="Country Code",data=total_top_ten_countries,palette="pastel")
plt.title("bottom ten countries by population(2024)",fontsize=10)
plt.title("total population",fontsize=10)
plt.ylabel("country",fontsize=10)
plt.show()
# Out:
# C:\Users\WELCOME\AppData\Local\Temp\ipykernel_4660\4211961035.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x="2020",y="Country Code",data=total_top_ten_countries,palette="pastel")
# C:\Users\WELCOME\AppData\Local\Temp\ipykernel_4660\4211961035.py:11: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x="2024",y="Country Code",data=total_top_ten_countries,palette="pastel")

# %%
# !pip install pandas
# !pip install bar_chart_race

import pandas as pd
import bar_chart_race as bcr
from IPython.display import Image  # For showing GIF inline
population = pd.read_csv("population.csv", skiprows=4)
population.columns = population.columns.str.strip()

year_cols = [str(y) for y in range(1960, 2024) if str(y) in population.columns]
df = population[['Country Name'] + year_cols].set_index('Country Name')

df = df.T
df.index.name = 'Year'
df.fillna(0, inplace=True)

bcr.bar_chart_race(
    df=df,
    filename='top10_population.gif',  # Save animation
    n_bars=10,
    title='Top 10 Most Populous Countries (1960–2023)',
    period_fmt='%Y',
    period_length=500,
    sort='desc',
    interpolate_period=True
)
Image(filename='top10_population.gif')
